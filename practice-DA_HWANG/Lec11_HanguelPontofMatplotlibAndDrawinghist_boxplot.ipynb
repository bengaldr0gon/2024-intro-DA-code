# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
import matplotlib.pyplot as plt

plt.plot([-2, -1, 0, 1, 2, 3], [20, 30, 15, 40, 56, 35], label ='선 1')
plt.plot([-2, -1, 0, 1, 2, 3], [25, 10, 35, 20, 15, 25], label ='선 2')
plt.title('선 그래프 예제')
plt.xlabel('x축')
plt.ylabel('y축')
plt.legend()
plt.show()

# %%
import matplotlib as mpl
from matplotlib import font_manager

# %%
font_list = sorted([f.name for f in font_manager.fontManager.ttflist])
'Malgun Gothic' in font_list
# Out:
# True

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malugn Gothic')
plt.rcParams['font.family'] = 'Malgun Gothic'

plt.title('선 그래프 예제')
plt.show()

# %%
plt.rc('font', family='Malgun Gothic') # 폰트 설정/ but, '-'는 깨져서 나옴
plt.plot([-2, -1, 0, 1, 2, 3], [20, 30, 15, 40, 45, 35], label='선 1')
plt.plot([-2, -1, 0, 1, 2, 3], [-25, 10, 35, 20, 15, 25], label='선 2')
plt.title('x축')
plt.ylabel('y축')
plt.legend()
plt.show()

# %%
plt.rc('axes', unicode_minus = False)
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# '-' 깨짐 설정

# %%
plt.rc('font', family='Malgun Gothic') # 폰트 설정/ but, '-'는 깨져서 나옴
plt.plot([-2, -1, 0, 1, 2, 3], [20, 30, 15, 40, 45, 35], label='선 1')
plt.plot([-2, -1, 0, 1, 2, 3], [-25, 10, 35, 20, 15, 25], label='선 2')
plt.title('x축')
plt.ylabel('y축')
plt.legend()
plt.show()

# %%
import numpy as np

x= np.arange(-10, 10, 0.1)
plt.plot(x, x**2)

plt.xticks(np.arange(-10, 11, 2))
plt.yticks(np.arange(0, 101, 20))

plt.rc('font', family='Malgun Gothic')
plt.title('선 그래프 예제')
# Out:
# Text(0.5, 1.0, '선 그래프 예제')

# %%
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

x = np.arange(-10, 10 ,0.1)
plt.plot(x, x**2)

plt.xticks(np.arange(-10, 11, 2)) # x 눈금
plt.yticks(np.arange(0, 101, 10)) # y 눈금
plt.grid(True) #격자

plt.title('선 그래프 예제')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 6, 7, 8, 10])
plt.show()

# %%
count, bins, c = plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10]) 
#count : 각 구간의 빈도수 배열
#bins : 각 구간을 나누는 수 배열
plt.show()
print(count)
print(bins)
# Out:
# [2. 1. 1. 1. 1. 2. 1. 1. 0. 1.]
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]

# %%
data = [1, 1, 2, 3, 4, 5, 6, 6, 8, 10]
arrays, bins, patches = plt.hist(data, bins=np.arange(0.5, 11.5), rwidth=.9) # rwidths를 통해 hist그래프를 분리(?) 할 수 있음.
plt.xticks(np.arange(11))
plt.show()

# %%
import random 

print(random.randint(1, 6))
# Out:
# 1

# %%
import random as rd

dice = []
for i in range(5):
    dice.append(rd.randint(1, 6))
print(dice)

dice = [rd.randint(1, 6) for i in range(5)]
print(dice)
# Out:
# [2, 4, 1, 4, 2]
# [1, 6, 2, 3, 4]

# %%
import random as rd 
import numpy as np
import matplotlib.pyplot as plt

dice = [rd.randint(1, 6) for i in range(5)]
plt.hist(dice, bins=np.arange(0.5, 7), rwidth=.9)
plt.xticks(range(1, 7))
plt.show()
